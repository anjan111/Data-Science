# %% [markdown]
# Figure aesthetics
# ==

# %% [markdown]
# ___
# # Setting colors in Matplotlib

# %% [markdown]
# ## Using specific colors in the color cycle

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
years = list(range(2009,2017))
android = [6.8,67.22,220.67,451.62,761.29,1004.68,1160.21,1271.02]
ios = [24.89,46.6,89.27,130.13,150.79,191.43,225.85,216.07]
microsoft = [15.03,12.38,8.76,16.94,30.71,35.13,26.74,6.94]
plt.plot(years,android,label='Android') # color='C0' by default
plt.plot(years,ios,label='iOS') # color='C1' by default
plt.plot(years,microsoft,label='Microsoft') # color='C2' by default
plt.legend()
plt.show()

# %% [markdown]
# ## Aesthetic and readability considerations

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# Prepare 4 lines with different slopes
x = np.linspace(0,200,100) # Prepare 100 evenly spaced numbers from 0 to200
# X = [0,2,4,6,8,10 -------198]
y1 = x*2
# y1 = [0,4,8,12,16,20,44------396]
y2 = x*3
# y2 = [0,6,12 ,18-----------]
y3 = x*4
y4 = x*5
# Set line width to 2 for clarity
mpl.rcParams['lines.linewidth'] = 2
# Drawing the 4 lines
plt.plot(x,y1,label = '2x', c='0')                   # Black solid line
plt.plot(x,y2,label = '3x', c='0.2', ls='--')        # Dark grey dashed line
plt.plot(x,y3,label = '4x', c='0.4', ls='-.')        # Grey dash-dot line
plt.plot(x,y4,label = '5x', c='0.6', ls=':')         # Light grey dotted line
plt.legend()
plt.show()

# %%
# This is a negative example
# Draw the 4 lines
# this line is too faint
plt.plot(x,y1,label = '2x', c='0.9') # light grey
plt.plot(x,y2,label = '3x', c='0.99') # very faint grey line
plt.plot(x,y3,label = '4x', c='0.4') # grey
plt.plot(x,y4,label = '5x', c='0.45') # slightly lighter grey
plt.legend()
plt.show()

# %% [markdown]
# ___
# # Adjusting text formats

# %% [markdown]
# ## Font

# %% [markdown]
# ### Font appearance

# %%
import matplotlib.pyplot as plt
fontparams = {'size':16,'fontweight':'light','family':'monospace','style':'normal'}
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)
plt.xlabel('xlabel',size=20,fontweight='semibold',family='serif',style='italic')
plt.ylabel('ylabel',fontparams)
plt.show()

# %% [markdown]
# ## Checking available fonts in system

# %%
# Run this cell to see the fonts installed in your system
from matplotlib.font_manager import findSystemFonts
findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# [u'C:\\Windows\\Fonts\\cour.ttf',
#  u'c:\\windows\\fonts\\ftltlt.ttf',
#  u'C:\\Windows\\Fonts\\seguisbi.ttf',
#  u'C:\\Windows\\Fonts\\STENCIL.TTF',
#  u'c:\\windows\\fonts\\cambriab.ttf',
#  u'C:\\Windows\\Fonts\\palabi.ttf',
#  u'C:\\Windows\\Fonts\\taileb.ttf',
#  u'c:\\windows\\fonts\\trebucbd.ttf',
#  u'c:\\windows\\fonts\\belli.ttf',
#  u'c:\\windows\\fonts\\bod_blai.ttf',
#  u'C:\\Windows\\Fonts\\COPRGTB.TTF',
#  u'C:\\Windows\\Fonts\\ELEPHNTI.TTF',
#  u'C:\\Windows\\Fonts\\malgunsl.ttf',
#  u'C:\\Windows\\Fonts\\seguibli.ttf',
#  u'C:\\Windows\\Fonts\\javatext.ttf',
#  u'C:\\Windows\\Fonts\\framdit.ttf',
#  u'c:\\windows\\fonts\\taileb.ttf',
#  u'c:\\windows\\fonts\\fradm.ttf',
#  u'c:\\windows\\fonts\\trebucbi.ttf',
#  u'c:\\windows\\fonts\\mtcorsva.ttf',
#  u'c:\\windows\\fonts\\segoeuiz.ttf',
#  u'c:\\windows\\fonts\\bod_cr.ttf',
#  u'c:\\windows\\fonts\\bod_bi.ttf',
#  u'c:\\windows\\fonts\\gili____.ttf',
#  u'c:\\windows\\fonts\\seguibli.ttf',
#  u'C:\\Windows\\Fonts\\malgunbd.ttf',
#  u'c:\\windows\\fonts\\imprisha.ttf',
#  u'C:\\Windows\\Fonts\\CURLZ___.TTF',
#  u'c:\\windows\\fonts\\ariali.ttf',
#  u'c:\\windows\\fonts\\tcm_____.ttf',
#  u'c:\\windows\\fonts\\magnetob.ttf',
#  u'c:\\windows\\fonts\\tccb____.ttf',
#  u'c:\\windows\\fonts\\seguisb.ttf',
#  u'C:\\Windows\\Fonts\\FRAHV.TTF',
#  u'C:\\Windows\\Fonts\\calibril.ttf',
#  u'C:\\Windows\\Fonts\\HTOWERTI.TTF',
#  u'C:\\Windows\\Fonts\\georgiai.ttf',
#  u'c:\\windows\\fonts\\kalam-regular.ttf',
#  u'C:\\Windows\\Fonts\\BOD_I.TTF',
#  u'c:\\windows\\fonts\\permanentmarker.ttf',
#  u'C:\\Windows\\Fonts\\ONYX.TTF',
#  u'C:\\Windows\\Fonts\\BASKVILL.TTF',
#  u'C:\\Windows\\Fonts\\LTYPEO.TTF',
#  u'C:\\Windows\\Fonts\\himalaya.ttf',
#  u'c:\\windows\\fonts\\tahomabd.ttf',
#  u'C:\\Windows\\Fonts\\ebrima.ttf',
#  u'c:\\windows\\fonts\\califi.ttf',
#  u'c:\\windows\\fonts\\kunstler.ttf',
#  u'C:\\Windows\\Fonts\\seguihis.ttf',
#  u'c:\\windows\\fonts\\consola.ttf',
#  u'c:\\windows\\fonts\\arialnb.ttf',
#  u'c:\\windows\\fonts\\arialbd.ttf',
#  u'C:\\Windows\\Fonts\\LeelawUI.ttf',
#  u'c:\\windows\\fonts\\verdanaz.ttf',
#  u'c:\\windows\\fonts\\lfaxd.ttf',
#  u'C:\\Windows\\Fonts\\cambriaz.ttf',
#  u'C:\\Windows\\Fonts\\constanz.ttf',
#  u'c:\\windows\\fonts\\maian.ttf',
#  u'c:\\windows\\fonts\\frabkit.ttf',
#  u'C:\\Windows\\Fonts\\segoeuii.ttf',
#  u'C:\\Windows\\Fonts\\mvboli.ttf',
#  u'c:\\windows\\fonts\\onyx.ttf',
#  u'C:\\Windows\\Fonts\\LTYPEB.TTF',
#  u'C:\\Windows\\Fonts\\NirmalaS.ttf',
#  u'C:\\Windows\\Fonts\\CabinSketch-Bold.ttf',
#  u'c:\\windows\\fonts\\antquabi.ttf',
#  u'C:\\Windows\\Fonts\\TCMI____.TTF',
#  u'C:\\Windows\\Fonts\\Candarali.ttf',
#  u'C:\\Windows\\Fonts\\LSANS.TTF',
#  u'C:\\Windows\\Fonts\\comici.ttf',
#  u'C:\\Windows\\Fonts\\marlett.ttf',
#  u'c:\\windows\\fonts\\corbelb.ttf',
#  u'c:\\windows\\fonts\\gara.ttf',
#  u'C:\\Windows\\Fonts\\FRABK.TTF',
#  u'c:\\windows\\fonts\\infroman.ttf',
#  u'C:\\Windows\\Fonts\\FugazOne-Regular.ttf',
#  u'c:\\windows\\fonts\\agencyb.ttf',
#  u'C:\\Windows\\Fonts\\ARLRDBD.TTF',
#  u'c:\\windows\\fonts\\nirmala.ttf',
#  u'c:\\windows\\fonts\\coopbl.ttf',
#  u'c:\\windows\\fonts\\seguiemj.ttf',
#  u'c:\\windows\\fonts\\ltypebo.ttf',
#  u'C:\\Windows\\Fonts\\calibrii.ttf',
#  u'c:\\windows\\fonts\\bahnschrift.ttf',
#  u'C:\\Windows\\Fonts\\FTLTLT.TTF',
#  u'c:\\windows\\fonts\\mod20.ttf',
#  u'c:\\windows\\fonts\\schlbkbi.ttf',
#  u'c:\\windows\\fonts\\ocraext.ttf',
#  u'C:\\Windows\\Fonts\\trebucbi.ttf',
#  u'C:\\Windows\\Fonts\\GOUDOSB.TTF',
#  u'c:\\windows\\fonts\\lsansi.ttf',
#  u'c:\\windows\\fonts\\erasmd.ttf',
#  u'c:\\windows\\fonts\\verdanai.ttf',
#  u'C:\\Windows\\Fonts\\JOKERMAN.TTF',
#  u'C:\\Windows\\Fonts\\constanb.ttf',
#  u'c:\\windows\\fonts\\fradmit.ttf',
#  u'C:\\Windows\\Fonts\\WINGDNG2.TTF',
#  u'C:\\Windows\\Fonts\\BRITANIC.TTF',
#  u'c:\\windows\\fonts\\georgiaz.ttf',
#  u'C:\\Windows\\Fonts\\BOD_BLAI.TTF',
#  u'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  u'c:\\windows\\fonts\\sylfaen.ttf',
#  u'c:\\windows\\fonts\\roccb___.ttf',
#  u'C:\\Windows\\Fonts\\calibriz.ttf',
#  u'C:\\Windows\\Fonts\\timesbd.ttf',
#  u'C:\\Windows\\Fonts\\Kalam-Regular.ttf',
#  u'C:\\Windows\\Fonts\\ERASMD.TTF',
#  u'c:\\windows\\fonts\\nirmalas.ttf',
#  u'c:\\windows\\fonts\\schlbki.ttf',
#  u'C:\\Windows\\Fonts\\BKANT.TTF',
#  u'C:\\Windows\\Fonts\\LFAXD.TTF',
#  u'C:\\Windows\\Fonts\\GIGI.TTF',
#  u'c:\\windows\\fonts\\cambriai.ttf',
#  u'C:\\Windows\\Fonts\\ARIALN.TTF',
#  u'c:\\windows\\fonts\\quicksand-light.ttf',
#  u'c:\\windows\\fonts\\segoeui.ttf',
#  u'c:\\windows\\fonts\\gadugi.ttf',
#  u'C:\\Windows\\Fonts\\FRADMCN.TTF',
#  u'C:\\Windows\\Fonts\\ANTQUABI.TTF',
#  u'C:\\Windows\\Fonts\\taile.ttf',
#  u'C:\\Windows\\Fonts\\LFAXI.TTF',
#  u'C:\\Windows\\Fonts\\SCHLBKBI.TTF',
#  u'C:\\Windows\\Fonts\\BERNHC.TTF',
#  u'c:\\windows\\fonts\\bookosi.ttf',
#  u'C:\\Windows\\Fonts\\KUNSTLER.TTF',
#  u'c:\\windows\\fonts\\glecb.ttf',
#  u'C:\\Windows\\Fonts\\euphorig.ttf',
#  u'C:\\Windows\\Fonts\\CHILLER.TTF',
#  u'C:\\Windows\\Fonts\\framd.ttf',
#  u'C:\\Windows\\Fonts\\LSANSI.TTF',
#  u'c:\\windows\\fonts\\taile.ttf',
#  u'C:\\Windows\\Fonts\\Limelight-Regular.ttf',
#  u'c:\\windows\\fonts\\calibri.ttf',
#  u'C:\\Windows\\Fonts\\FELIXTI.TTF',
#  u'C:\\Windows\\Fonts\\VLADIMIR.TTF',
#  u'C:\\Windows\\Fonts\\impact.ttf',
#  u'c:\\windows\\fonts\\centaur.ttf',
#  u'C:\\Windows\\Fonts\\ITCEDSCR.TTF',
#  u'C:\\Windows\\Fonts\\BROADW.TTF',
#  u'C:\\Windows\\Fonts\\COLONNA.TTF',
#  u'C:\\Windows\\Fonts\\GILB____.TTF',
#  u'C:\\Windows\\Fonts\\wingding.ttf',
#  u'c:\\windows\\fonts\\corbelli.ttf',
#  u'c:\\windows\\fonts\\per_____.ttf',
#  u'c:\\windows\\fonts\\arlrdbd.ttf',
#  u'C:\\Windows\\Fonts\\CALISTBI.TTF',
#  u'c:\\windows\\fonts\\bernhc.ttf',
#  u'c:\\windows\\fonts\\quicksand-medium.ttf',
#  u'C:\\Windows\\Fonts\\l_10646.ttf',
#  u'c:\\windows\\fonts\\castelar.ttf',
#  u'C:\\Windows\\Fonts\\ANTQUAI.TTF',
#  u'C:\\Windows\\Fonts\\SCRIPTBL.TTF',
#  u'C:\\Windows\\Fonts\\BRLNSDB.TTF',
#  u'c:\\windows\\fonts\\arialuni.ttf',
#  u'c:\\windows\\fonts\\ebrimabd.ttf',
#  u'C:\\Windows\\Fonts\\UbuntuMono-Regular.ttf',
#  u'C:\\Windows\\Fonts\\segoepr.ttf',
#  u'C:\\Windows\\Fonts\\micross.ttf',
#  u'c:\\windows\\fonts\\gillubcd.ttf',
#  u'c:\\windows\\fonts\\mistral.ttf',
#  u'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  u'C:\\Windows\\Fonts\\GILBI___.TTF',
#  u'C:\\Windows\\Fonts\\PALSCRI.TTF',
#  u'C:\\Windows\\Fonts\\segoeprb.ttf',
#  u'c:\\windows\\fonts\\peri____.ttf',
#  u'c:\\windows\\fonts\\coprgtl.ttf',
#  u'c:\\windows\\fonts\\tcmi____.ttf',
#  u'C:\\Windows\\Fonts\\verdanai.ttf',
#  u'c:\\windows\\fonts\\segoepr.ttf',
#  u'c:\\windows\\fonts\\micross.ttf',
#  u'c:\\windows\\fonts\\times.ttf',
#  u'c:\\windows\\fonts\\wingdng2.ttf',
#  u'c:\\windows\\fonts\\consolab.ttf',
#  u'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  u'c:\\windows\\fonts\\couri.ttf',
#  u'c:\\windows\\fonts\\arial.ttf',
#  u'c:\\windows\\fonts\\bod_i.ttf',
#  u'C:\\Windows\\Fonts\\segoeuil.ttf',
#  u'C:\\Windows\\Fonts\\consolai.ttf',
#  u'c:\\windows\\fonts\\engr.ttf',
#  u'C:\\Windows\\Fonts\\LFAXDI.TTF',
#  u'C:\\Windows\\Fonts\\GOTHIC.TTF',
#  u'c:\\windows\\fonts\\l_10646.ttf',
#  u'C:\\Windows\\Fonts\\seguisb.ttf',
#  u'C:\\Windows\\Fonts\\seguili.ttf',
#  u'C:\\Windows\\Fonts\\CabinSketch-Regular.ttf',
#  u'c:\\windows\\fonts\\refsan.ttf',
#  u'c:\\windows\\fonts\\bookosb.ttf',
#  u'C:\\Windows\\Fonts\\calibri.ttf',
#  u'c:\\windows\\fonts\\felixti.ttf',
#  u'c:\\windows\\fonts\\inkfree.ttf',
#  u'C:\\Windows\\Fonts\\segoesc.ttf',
#  u'c:\\windows\\fonts\\palai.ttf',
#  u'c:\\windows\\fonts\\frahvit.ttf',
#  u'C:\\Windows\\Fonts\\malgun.ttf',
#  u'C:\\Windows\\Fonts\\BRLNSR.TTF',
#  u'c:\\windows\\fonts\\calibrib.ttf',
#  u'C:\\Windows\\Fonts\\constani.ttf',
#  u'C:\\Windows\\Fonts\\PERI____.TTF',
#  u'c:\\windows\\fonts\\bod_b.ttf',
#  u'c:\\windows\\fonts\\msmincho.ttf',
#  u'c:\\windows\\fonts\\schlbkb.ttf',
#  u'c:\\windows\\fonts\\chiller.ttf',
#  u'C:\\Windows\\Fonts\\ANTQUAB.TTF',
#  u'C:\\Windows\\Fonts\\CALISTI.TTF',
#  u'c:\\windows\\fonts\\constan.ttf',
#  u'C:\\Windows\\Fonts\\ARIALNI.TTF',
#  u'c:\\windows\\fonts\\trebuc.ttf',
#  u'C:\\Windows\\Fonts\\MATURASC.TTF',
#  u'c:\\windows\\fonts\\gil_____.ttf',
#  u'C:\\Windows\\Fonts\\GLSNECB.TTF',
#  u'c:\\windows\\fonts\\rockb.ttf',
#  u'c:\\windows\\fonts\\bowlbyonesc-regular.ttf',
#  u'C:\\Windows\\Fonts\\BRUSHSCI.TTF',
#  u'c:\\windows\\fonts\\cour.ttf',
#  u'C:\\Windows\\Fonts\\timesbi.ttf',
#  u'C:\\Windows\\Fonts\\HARNGTON.TTF',
#  u'c:\\windows\\fonts\\javatext.ttf',
#  u'c:\\windows\\fonts\\califr.ttf',
#  u'C:\\Windows\\Fonts\\CALIST.TTF',
#  u'C:\\Windows\\Fonts\\COOPBL.TTF',
#  u'C:\\Windows\\Fonts\\ariblk.ttf',
#  u'c:\\windows\\fonts\\censcbk.ttf',
#  u'C:\\Windows\\Fonts\\corbel.ttf',
#  u'C:\\Windows\\Fonts\\GLECB.TTF',
#  u'c:\\windows\\fonts\\candaral.ttf',
#  u'C:\\Windows\\Fonts\\NIAGSOL.TTF',
#  u'C:\\Windows\\Fonts\\msyi.ttf',
#  u'C:\\Windows\\Fonts\\calibrib.ttf',
#  u'C:\\Windows\\Fonts\\BOOKOSB.TTF',
#  u'c:\\windows\\fonts\\limelight-regular.ttf',
#  u'c:\\windows\\fonts\\tcbi____.ttf',
#  u'c:\\windows\\fonts\\verdanab.ttf',
#  u'C:\\Windows\\Fonts\\phagspab.ttf',
#  u'c:\\windows\\fonts\\courbi.ttf',
#  u'c:\\windows\\fonts\\phagspa.ttf',
#  u'c:\\windows\\fonts\\wingdng3.ttf',
#  u'c:\\windows\\fonts\\doppioone-regular.ttf',
#  u'c:\\windows\\fonts\\calistb.ttf',
#  u'C:\\Windows\\Fonts\\JUICE___.TTF',
#  u'c:\\windows\\fonts\\teko-semibold.ttf',
#  u'c:\\windows\\fonts\\calisti.ttf',
#  u'c:\\windows\\fonts\\cookie-regular.ttf',
#  u'C:\\Windows\\Fonts\\BRADHITC.TTF',
#  u'c:\\windows\\fonts\\vineritc.ttf',
#  u'c:\\windows\\fonts\\jokerman.ttf',
#  u'C:\\Windows\\Fonts\\segoeuib.ttf',
#  u'C:\\Windows\\Fonts\\GILLUBCD.TTF',
#  u'C:\\Windows\\Fonts\\Candaraz.ttf',
#  u'c:\\windows\\fonts\\itcblkad.ttf',
#  u'C:\\Windows\\Fonts\\BOD_CBI.TTF',
#  u'c:\\windows\\fonts\\baskvill.ttf',
#  u'C:\\Windows\\Fonts\\LFAX.TTF',
#  u'c:\\windows\\fonts\\malgunsl.ttf',
#  u'c:\\windows\\fonts\\rocki.ttf',
#  u'C:\\Windows\\Fonts\\Nirmala.ttf',
#  u'c:\\windows\\fonts\\bkant.ttf',
#  u'c:\\windows\\fonts\\calibril.ttf',
#  u'C:\\Windows\\Fonts\\HATTEN.TTF',
#  u'c:\\windows\\fonts\\garabd.ttf',
#  u'c:\\windows\\fonts\\seguibl.ttf',
#  u'c:\\windows\\fonts\\gilc____.ttf',
#  u'C:\\Windows\\Fonts\\BOD_CI.TTF',
#  u'C:\\Windows\\Fonts\\courbd.ttf',
#  u'C:\\Windows\\Fonts\\SNAP____.TTF',
#  u'c:\\windows\\fonts\\calist.ttf',
#  u'c:\\windows\\fonts\\curlz___.ttf',
#  u'c:\\windows\\fonts\\arialbi.ttf',
#  u'c:\\windows\\fonts\\trebucit.ttf',
#  u'C:\\Windows\\Fonts\\BOOKOSI.TTF',
#  u'c:\\windows\\fonts\\britanic.ttf',
#  u'c:\\windows\\fonts\\courbd.ttf',
#  u'c:\\windows\\fonts\\pertili.ttf',
#  u'C:\\Windows\\Fonts\\CALIFB.TTF',
#  u'c:\\windows\\fonts\\simsunb.ttf',
#  u'C:\\Windows\\Fonts\\TCCEB.TTF',
#  u'C:\\Windows\\Fonts\\REFSAN.TTF',
#  u'c:\\windows\\fonts\\framdit.ttf',
#  u'c:\\windows\\fonts\\bauhs93.ttf',
#  u'c:\\windows\\fonts\\lcallig.ttf',
#  u'C:\\Windows\\Fonts\\LTYPEBO.TTF',
#  u'c:\\windows\\fonts\\colonna.ttf',
#  u'c:\\windows\\fonts\\leelauib.ttf',
#  u'C:\\Windows\\Fonts\\Yellowtail-Regular.ttf',
#  u'c:\\windows\\fonts\\timesbi.ttf',
#  u'c:\\windows\\fonts\\comicbd.ttf',
#  u'c:\\windows\\fonts\\candarab.ttf',
#  u'C:\\Windows\\Fonts\\MOD20.TTF',
#  u'C:\\Windows\\Fonts\\LTYPE.TTF',
#  u'c:\\windows\\fonts\\tempsitc.ttf',
#  u'C:\\Windows\\Fonts\\Courgette-Regular.ttf',
#  u'c:\\windows\\fonts\\ltypeo.ttf',
#  u'C:\\Windows\\Fonts\\georgiaz.ttf',
#  u'C:\\Windows\\Fonts\\ERASLGHT.TTF',
#  u'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  u'C:\\Windows\\Fonts\\TCM_____.TTF',
#  u'c:\\windows\\fonts\\goudysto.ttf',
#  u'C:\\Windows\\Fonts\\arialbi.ttf',
#  u'C:\\Windows\\Fonts\\Quicksand-Medium.ttf',
#  u'c:\\windows\\fonts\\calibrili.ttf',
#  u'c:\\windows\\fonts\\palab.ttf',
#  u'C:\\Windows\\Fonts\\ROCCB___.TTF',
#  u'C:\\Windows\\Fonts\\cambriai.ttf',
#  u'C:\\Windows\\Fonts\\CALIFR.TTF',
#  u'c:\\windows\\fonts\\glsnecb.ttf',
#  u'c:\\windows\\fonts\\frabk.ttf',
#  u'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  u'C:\\Windows\\Fonts\\corbelli.ttf',
#  u'c:\\windows\\fonts\\goudosb.ttf',
#  u'c:\\windows\\fonts\\eraslght.ttf',
#  u'c:\\windows\\fonts\\constanb.ttf',
#  u'C:\\Windows\\Fonts\\segmdl2.ttf',
#  u'c:\\windows\\fonts\\pertibd.ttf',
#  u'C:\\Windows\\Fonts\\PARCHM.TTF',
#  u'c:\\windows\\fonts\\elephnti.ttf',
#  u'C:\\Windows\\Fonts\\timesi.ttf',
#  u'c:\\windows\\fonts\\gothicbi.ttf',
#  u'C:\\Windows\\Fonts\\Gabriola.ttf',
#  u'c:\\windows\\fonts\\harngton.ttf',
#  u'c:\\windows\\fonts\\calibriz.ttf',
#  u'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  u'c:\\windows\\fonts\\comici.ttf',
#  u'C:\\Windows\\Fonts\\VINERITC.TTF',
#  u'C:\\Windows\\Fonts\\BOD_CB.TTF',
#  u'C:\\Windows\\Fonts\\ENGR.TTF',
#  u'C:\\Windows\\Fonts\\Candarai.ttf',
#  u'C:\\Windows\\Fonts\\ITCBLKAD.TTF',
#  u'c:\\windows\\fonts\\garait.ttf',
#  u'C:\\Windows\\Fonts\\trebucbd.ttf',
#  u'C:\\Windows\\Fonts\\couri.ttf',
#  u'c:\\windows\\fonts\\gilb____.ttf',
#  u'C:\\Windows\\Fonts\\verdanaz.ttf',
#  u'C:\\Windows\\Fonts\\BowlbyOneSC-Regular.ttf',
#  u'c:\\windows\\fonts\\century.ttf',
#  u'c:\\windows\\fonts\\constanz.ttf',
#  u'C:\\Windows\\Fonts\\monbaiti.ttf',
#  u'c:\\windows\\fonts\\gilbi___.ttf',
#  u'c:\\windows\\fonts\\outlook.ttf',
#  u'C:\\Windows\\Fonts\\sylfaen.ttf',
#  u'c:\\windows\\fonts\\lfaxdi.ttf',
#  u'c:\\windows\\fonts\\candara.ttf',
#  u'C:\\Windows\\Fonts\\COPRGTL.TTF',
#  u'C:\\Windows\\Fonts\\PER_____.TTF',
#  u'c:\\windows\\fonts\\arialn.ttf',
#  u'c:\\windows\\fonts\\lfax.ttf',
#  u'C:\\Windows\\Fonts\\GILI____.TTF',
#  u'C:\\Windows\\Fonts\\comicbd.ttf',
#  u'C:\\Windows\\Fonts\\RAGE.TTF',
#  u'c:\\windows\\fonts\\hatten.ttf',
#  u'C:\\Windows\\Fonts\\PERBI___.TTF',
#  u'C:\\Windows\\Fonts\\BungeeInline-Regular.ttf',
#  u'c:\\windows\\fonts\\brlnsr.ttf',
#  u'C:\\Windows\\Fonts\\LATINWD.TTF',
#  u'C:\\Windows\\Fonts\\BSSYM7.TTF',
#  u'c:\\windows\\fonts\\msyi.ttf',
#  u'c:\\windows\\fonts\\wingding.ttf',
#  u'C:\\Windows\\Fonts\\Orbitron-Bold.ttf',
#  u'c:\\windows\\fonts\\bell.ttf',
#  u'C:\\Windows\\Fonts\\corbelz.ttf',
#  u'C:\\Windows\\Fonts\\FORTE.TTF',
#  u'C:\\Windows\\Fonts\\BOD_B.TTF',
#  u'c:\\windows\\fonts\\segoescb.ttf',
#  u'C:\\Windows\\Fonts\\arialbd.ttf',
#  u'C:\\Windows\\Fonts\\FRAHVIT.TTF',
#  u'C:\\Windows\\Fonts\\comic.ttf',
#  u'C:\\Windows\\Fonts\\TCCM____.TTF',
#  u'c:\\windows\\fonts\\juice___.ttf',
#  u'C:\\Windows\\Fonts\\FRSCRIPT.TTF',
#  u'C:\\Windows\\Fonts\\SCHLBKB.TTF',
#  u'c:\\windows\\fonts\\quicksand-regular.ttf',
#  u'c:\\windows\\fonts\\lsans.ttf',
#  u'C:\\Windows\\Fonts\\MISTRAL.TTF',
#  u'c:\\windows\\fonts\\framdcn.ttf',
#  u'C:\\Windows\\Fonts\\consola.ttf',
#  u'C:\\Windows\\Fonts\\GARABD.TTF',
#  u'C:\\Windows\\Fonts\\FRABKIT.TTF',
#  u'C:\\Windows\\Fonts\\Quicksand-Light.ttf',
#  u'C:\\Windows\\Fonts\\CASTELAR.TTF',
#  u'c:\\windows\\fonts\\antquab.ttf',
#  u'C:\\Windows\\Fonts\\Teko-SemiBold.ttf',
#  u'c:\\windows\\fonts\\brushsci.ttf',
#  u'c:\\windows\\fonts\\fugazone-regular.ttf',
#  u'c:\\windows\\fonts\\freescpt.ttf',
#  u'c:\\windows\\fonts\\greatvibes-regular.ttf',
#  u'c:\\windows\\fonts\\bod_ci.ttf',
#  u'C:\\Windows\\Fonts\\BELL.TTF',
#  u'c:\\windows\\fonts\\gilsanub.ttf',
#  u'C:\\Windows\\Fonts\\PAPYRUS.TTF',
#  u'c:\\windows\\fonts\\gigi.ttf',
#  u'C:\\Windows\\Fonts\\BAUHS93.TTF',
#  u'C:\\Windows\\Fonts\\LBRITED.TTF',
#  u'C:\\Windows\\Fonts\\BRLNSB.TTF',
#  u'c:\\windows\\fonts\\cabinsketch-regular.ttf',
#  u'C:\\Windows\\Fonts\\CALISTB.TTF',
#  u'c:\\windows\\fonts\\latinwd.ttf',
#  u'c:\\windows\\fonts\\htowert.ttf',
#  u'c:\\windows\\fonts\\papyrus.ttf',
#  u'c:\\windows\\fonts\\lbritedi.ttf',
#  u'C:\\Windows\\Fonts\\Megrim.ttf',
#  u'c:\\windows\\fonts\\elephnt.ttf',
#  u'c:\\windows\\fonts\\cinzel-black.ttf',
#  u'c:\\windows\\fonts\\ariblk.ttf',
#  u'C:\\Windows\\Fonts\\ntailu.ttf',
#  u'C:\\Windows\\Fonts\\FRAMDCN.TTF',
#  u'c:\\windows\\fonts\\fradmcn.ttf',
#  u'c:\\windows\\fonts\\consolaz.ttf',
#  u'c:\\windows\\fonts\\bookosbi.ttf',
#  u'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  u'C:\\Windows\\Fonts\\ROCKI.TTF',
#  u'C:\\Windows\\Fonts\\TEMPSITC.TTF',
#  u'C:\\Windows\\Fonts\\trebuc.ttf',
#  u'C:\\Windows\\Fonts\\corbeli.ttf',
#  u'C:\\Windows\\Fonts\\consolab.ttf',
#  u'c:\\windows\\fonts\\lemon-regular.ttf',
#  u'c:\\windows\\fonts\\rock.ttf',
#  u'c:\\windows\\fonts\\corbell.ttf',
#  u'C:\\Windows\\Fonts\\AGENCYB.TTF',
#  u'C:\\Windows\\Fonts\\RussoOne-Regular.ttf',
#  u'c:\\windows\\fonts\\lsansdi.ttf',
#  u'c:\\windows\\fonts\\corbeli.ttf',
#  u'c:\\windows\\fonts\\tcb_____.ttf',
#  u'C:\\Windows\\Fonts\\FRADMIT.TTF',
#  u'C:\\Windows\\Fonts\\GOTHICB.TTF',
#  u'c:\\windows\\fonts\\rockbi.ttf',
#  u'C:\\Windows\\Fonts\\georgia.ttf',
#  u'c:\\windows\\fonts\\himalaya.ttf',
#  u'c:\\windows\\fonts\\calibrii.ttf',
#  u'c:\\windows\\fonts\\timesi.ttf',
#  u'C:\\Windows\\Fonts\\MarcellusSC-Regular.ttf',
#  u'C:\\Windows\\Fonts\\UbuntuMono-Bold.ttf',
#  u'C:\\Windows\\Fonts\\ELEPHNT.TTF',
#  u'C:\\Windows\\Fonts\\courbi.ttf',
#  u'C:\\Windows\\Fonts\\corbelb.ttf',
#  u'C:\\Windows\\Fonts\\OCRAEXT.TTF',
#  u'C:\\Windows\\Fonts\\georgiab.ttf',
#  u'C:\\Windows\\Fonts\\palai.ttf',
#  u'c:\\windows\\fonts\\euphorig.ttf',
#  u'C:\\Windows\\Fonts\\BELLI.TTF',
#  u'C:\\Windows\\Fonts\\ERASBD.TTF',
#  u'C:\\Windows\\Fonts\\GARAIT.TTF',
#  u'C:\\Windows\\Fonts\\seguisli.ttf',
#  u'c:\\windows\\fonts\\alger.ttf',
#  u'c:\\windows\\fonts\\maturasc.ttf',
#  u'c:\\windows\\fonts\\ltype.ttf',
#  u'C:\\Windows\\Fonts\\GARA.TTF',
#  u'C:\\Windows\\Fonts\\FRADM.TTF',
#  u'C:\\Windows\\Fonts\\RAVIE.TTF',
#  u'c:\\windows\\fonts\\palscri.ttf',
#  u'C:\\Windows\\Fonts\\tahomabd.ttf',
#  u'c:\\windows\\fonts\\niagsol.ttf',
#  u'c:\\windows\\fonts\\gothic.ttf',
#  u'c:\\windows\\fonts\\seguili.ttf',
#  u'C:\\Windows\\Fonts\\Kalam-Bold.ttf',
#  u'c:\\windows\\fonts\\malgunbd.ttf',
#  u'c:\\windows\\fonts\\pristina.ttf',
#  u'C:\\Windows\\Fonts\\Cinzel-Black.ttf',
#  u'C:\\Windows\\Fonts\\webdings.ttf',
#  u'c:\\windows\\fonts\\ntailu.ttf',
#  u'C:\\Windows\\Fonts\\calibrili.ttf',
#  u'c:\\windows\\fonts\\califb.ttf',
#  u'c:\\windows\\fonts\\lfaxi.ttf',
#  u'c:\\windows\\fonts\\frahv.ttf',
#  u'C:\\Windows\\Fonts\\NIAGENG.TTF',
#  u'c:\\windows\\fonts\\candarali.ttf',
#  u'C:\\Windows\\Fonts\\REFSPCL.TTF',
#  u'c:\\windows\\fonts\\symbol.ttf',
#  u'c:\\windows\\fonts\\webdings.ttf',
#  u'c:\\windows\\fonts\\shrikhand-regular.ttf',
#  u'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  u'C:\\Windows\\Fonts\\INFROMAN.TTF',
#  u'C:\\Windows\\Fonts\\GreatVibes-Regular.ttf',
#  u'C:\\Windows\\Fonts\\comicz.ttf',
#  u'c:\\windows\\fonts\\consolai.ttf',
#  u'c:\\windows\\fonts\\refspcl.ttf',
#  u'c:\\windows\\fonts\\goudosi.ttf',
#  u'c:\\windows\\fonts\\antquai.ttf',
#  u'c:\\windows\\fonts\\georgia.ttf',
#  u'c:\\windows\\fonts\\lbrite.ttf',
#  u'C:\\Windows\\Fonts\\verdana.ttf',
#  u'c:\\windows\\fonts\\segoeuii.ttf',
#  u'c:\\windows\\fonts\\frscript.ttf',
#  u'C:\\Windows\\Fonts\\ROCK.TTF',
#  u'c:\\windows\\fonts\\monbaiti.ttf',
#  u'C:\\Windows\\Fonts\\ARIALNBI.TTF',
#  u'c:\\windows\\fonts\\nirmalab.ttf',
#  u'c:\\windows\\fonts\\seguihis.ttf',
#  u'c:\\windows\\fonts\\bod_blar.ttf',
#  u'c:\\windows\\fonts\\coprgtb.ttf',
#  u'c:\\windows\\fonts\\corbel.ttf',
#  u'C:\\Windows\\Fonts\\mmrtext.ttf',
#  u'C:\\Windows\\Fonts\\GOUDOSI.TTF',
#  u'C:\\Windows\\Fonts\\segoeui.ttf',
#  u'c:\\windows\\fonts\\sigmarone-regular.ttf',
#  u'C:\\Windows\\Fonts\\BOD_BI.TTF',
#  u'C:\\Windows\\Fonts\\corbell.ttf',
#  u'c:\\windows\\fonts\\timesbd.ttf',
#  u'c:\\windows\\fonts\\rocc____.ttf',
#  u'c:\\windows\\fonts\\playball-regular.ttf',
#  u'c:\\windows\\fonts\\ubuntumono-regular.ttf',
#  u'C:\\Windows\\Fonts\\Kalam-Light.ttf',
#  u'C:\\Windows\\Fonts\\seguibl.ttf',
#  u'c:\\windows\\fonts\\mmrtext.ttf',
#  u'c:\\windows\\fonts\\segoesc.ttf',
#  u'c:\\windows\\fonts\\segoeuisl.ttf',
#  u'C:\\Windows\\Fonts\\VIVALDII.TTF',
#  u'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  u'C:\\Windows\\Fonts\\palab.ttf',
#  u'c:\\windows\\fonts\\marcellussc-regular.ttf',
#  u'C:\\Windows\\Fonts\\SHOWG.TTF',
#  u'C:\\Windows\\Fonts\\Cookie-Regular.ttf',
#  u'c:\\windows\\fonts\\russoone-regular.ttf',
#  u'C:\\Windows\\Fonts\\arial.ttf',
#  u'c:\\windows\\fonts\\corbelz.ttf',
#  u'c:\\windows\\fonts\\kalam-light.ttf',
#  u'C:\\Windows\\Fonts\\tahoma.ttf',
#  u'C:\\Windows\\Fonts\\MAGNETOB.TTF',
#  u'c:\\windows\\fonts\\tccm____.ttf',
#  u'c:\\windows\\fonts\\candarai.ttf',
#  u'c:\\windows\\fonts\\comic.ttf',
#  u'c:\\windows\\fonts\\segoeprb.ttf',
#  u'C:\\Windows\\Fonts\\simsunb.ttf',
#  u'c:\\windows\\fonts\\mmrtextb.ttf',
#  u'c:\\windows\\fonts\\bungeeinline-regular.ttf',
#  u'C:\\Windows\\Fonts\\IMPRISHA.TTF',
#  u'C:\\Windows\\Fonts\\LSANSD.TTF',
#  u'C:\\Windows\\Fonts\\verdanab.ttf',
#  u'c:\\windows\\fonts\\tahoma.ttf',
#  u'c:\\windows\\fonts\\gothicb.ttf',
#  u'c:\\windows\\fonts\\brlnsb.ttf',
#  u'c:\\windows\\fonts\\vivaldii.ttf',
#  u'C:\\Windows\\Fonts\\PLAYBILL.TTF',
#  u'C:\\Windows\\Fonts\\Playball-Regular.ttf',
#  u'c:\\windows\\fonts\\bookos.ttf',
#  u'c:\\windows\\fonts\\framd.ttf',
#  u'C:\\Windows\\Fonts\\CALIFI.TTF',
#  u'c:\\windows\\fonts\\brlnsdb.ttf',
#  u'c:\\windows\\fonts\\perb____.ttf',
#  u'C:\\Windows\\Fonts\\symbol.ttf',
#  u'c:\\windows\\fonts\\comicz.ttf',
#  u'c:\\windows\\fonts\\rage.ttf',
#  u'c:\\windows\\fonts\\arialnbi.ttf',
#  u'c:\\windows\\fonts\\bod_cb.ttf',
#  u'c:\\windows\\fonts\\parchm.ttf',
#  u'c:\\windows\\fonts\\harlowsi.ttf',
#  u'C:\\Windows\\Fonts\\gadugib.ttf',
#  u'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  u'C:\\Windows\\Fonts\\POORICH.TTF',
#  u'c:\\windows\\fonts\\seguisli.ttf',
#  u'c:\\windows\\fonts\\impact.ttf',
#  u'c:\\windows\\fonts\\malgun.ttf',
#  u'C:\\Windows\\Fonts\\BOD_CR.TTF',
#  u'c:\\windows\\fonts\\showg.ttf',
#  u'c:\\windows\\fonts\\arialni.ttf',
#  u'C:\\Windows\\Fonts\\LSANSDI.TTF',
#  u'c:\\windows\\fonts\\gothici.ttf',
#  u'C:\\Windows\\Fonts\\cambriab.ttf',
#  u'C:\\Windows\\Fonts\\ROCKEB.TTF',
#  u'C:\\Windows\\Fonts\\ERASDEMI.TTF',
#  u'c:\\windows\\fonts\\orbitron-bold.ttf',
#  u'c:\\windows\\fonts\\megrim.ttf',
#  u'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  u'c:\\windows\\fonts\\georgiai.ttf',
#  u'C:\\Windows\\Fonts\\seguiemj.ttf',
#  u'C:\\Windows\\Fonts\\LBRITE.TTF',
#  u'c:\\windows\\fonts\\forte.ttf',
#  u'c:\\windows\\fonts\\pala.ttf',
#  u'C:\\Windows\\Fonts\\Inkfree.ttf',
#  u'C:\\Windows\\Fonts\\AGENCYR.TTF',
#  u'c:\\windows\\fonts\\goudos.ttf',
#  u'c:\\windows\\fonts\\tcceb.ttf',
#  u'C:\\Windows\\Fonts\\ARIALUNI.TTF',
#  u'C:\\Windows\\Fonts\\ALGER.TTF',
#  u'c:\\windows\\fonts\\stencil.ttf',
#  u'C:\\Windows\\Fonts\\ariali.ttf',
#  u'c:\\windows\\fonts\\seguisym.ttf',
#  u'C:\\Windows\\Fonts\\BOD_BLAR.TTF',
#  u'c:\\windows\\fonts\\snap____.ttf',
#  u'c:\\windows\\fonts\\candaraz.ttf',
#  u'c:\\windows\\fonts\\agencyr.ttf',
#  u'c:\\windows\\fonts\\itcedscr.ttf',
#  u'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  u'C:\\Windows\\Fonts\\SCHLBKI.TTF',
#  u'c:\\program files (x86)\\common files\\microsoft shared\\equation\\mtextra.ttf',
#  u'c:\\windows\\fonts\\cambriaz.ttf',
#  u'C:\\Windows\\Fonts\\GOUDYSTO.TTF',
#  u'C:\\Windows\\Fonts\\ITCKRIST.TTF',
#  u'C:\\Windows\\Fonts\\PermanentMarker.ttf',
#  u'C:\\Windows\\Fonts\\CENSCBK.TTF',
#  u'c:\\windows\\fonts\\georgiab.ttf',
#  u'c:\\windows\\fonts\\courgette-regular.ttf',
#  u'C:\\Windows\\Fonts\\constan.ttf',
#  u'c:\\windows\\fonts\\niageng.ttf',
#  u'c:\\windows\\fonts\\montserratsubrayada-bold.ttf',
#  u'C:\\Windows\\Fonts\\ROCKBI.TTF',
#  u'c:\\windows\\fonts\\lsansd.ttf',
#  u'C:\\Windows\\Fonts\\pala.ttf',
#  u'c:\\windows\\fonts\\seguisbi.ttf',
#  u'C:\\Windows\\Fonts\\ROCC____.TTF',
#  u'c:\\windows\\fonts\\segoeuib.ttf',
#  u'c:\\windows\\fonts\\gadugib.ttf',
#  u'C:\\Windows\\Fonts\\MTCORSVA.TTF',
#  u'C:\\Windows\\Fonts\\OUTLOOK.TTF',
#  u'c:\\windows\\fonts\\segoeuil.ttf',
#  u'c:\\windows\\fonts\\lbritei.ttf',
#  u'C:\\Windows\\Fonts\\BOD_R.TTF',
#  u'C:\\Windows\\Fonts\\Lemon-Regular.ttf',
#  u'c:\\windows\\fonts\\htowerti.ttf',
#  u'c:\\windows\\fonts\\itckrist.ttf',
#  u'c:\\windows\\fonts\\lbrited.ttf',
#  u'C:\\Windows\\Fonts\\trebucit.ttf',
#  u'C:\\Windows\\Fonts\\DoppioOne-Regular.ttf',
#  u'C:\\Windows\\Fonts\\GILC____.TTF',
#  u'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  u'c:\\windows\\fonts\\ebrima.ttf',
#  u'c:\\windows\\fonts\\bradhitc.ttf',
#  u'C:\\Windows\\Fonts\\lucon.ttf',
#  u'C:\\Windows\\Fonts\\CENTURY.TTF',
#  u'C:\\Windows\\Fonts\\LHANDW.TTF',
#  u'C:\\Windows\\Fonts\\GIL_____.TTF',
#  u'C:\\Windows\\Fonts\\OLDENGL.TTF',
#  u'C:\\Windows\\Fonts\\ROCKB.TTF',
#  u'c:\\windows\\fonts\\vladimir.ttf',
#  u'C:\\Windows\\Fonts\\ARIALNB.TTF',
#  u'c:\\windows\\fonts\\erasbd.ttf',
#  u'c:\\windows\\fonts\\bssym7.ttf',
#  u'C:\\Windows\\Fonts\\Quicksand-Bold.ttf',
#  u'C:\\Windows\\Fonts\\segoescb.ttf',
#  u'C:\\Windows\\Fonts\\gadugi.ttf',
#  u'c:\\windows\\fonts\\leeluisl.ttf',
#  u'C:\\Windows\\Fonts\\Shrikhand-Regular.ttf',
#  u'C:\\Windows\\Fonts\\CENTAUR.TTF',
#  u'C:\\Windows\\Fonts\\MontserratSubrayada-Bold.ttf',
#  u'c:\\windows\\fonts\\verdana.ttf',
#  u'C:\\Windows\\Fonts\\Candara.ttf',
#  u'C:\\Windows\\Fonts\\ntailub.ttf',
#  u'c:\\windows\\fonts\\lhandw.ttf',
#  u'C:\\Windows\\Fonts\\PRISTINA.TTF',
#  u'c:\\windows\\fonts\\rockeb.ttf',
#  u'C:\\Windows\\Fonts\\NotoSans-Regular.ttf',
#  u'c:\\windows\\fonts\\playbill.ttf',
#  u'c:\\windows\\fonts\\ltypeb.ttf',
#  u'C:\\Windows\\Fonts\\GOTHICBI.TTF',
#  u'C:\\Windows\\Fonts\\BELLB.TTF',
#  u'c:\\windows\\fonts\\bod_r.ttf',
#  u'c:\\windows\\fonts\\bod_pstc.ttf',
#  u'C:\\Windows\\Fonts\\seguisym.ttf',
#  u'c:\\windows\\fonts\\constani.ttf',
#  u'C:\\Windows\\Fonts\\times.ttf',
#  u'C:\\Windows\\Fonts\\SigmarOne-Regular.ttf',
#  u'C:\\Windows\\Fonts\\FREESCPT.TTF',
#  u'c:\\windows\\fonts\\gabriola.ttf',
#  u'C:\\Windows\\Fonts\\TCBI____.TTF',
#  u'c:\\windows\\fonts\\perbi___.ttf',
#  u'c:\\windows\\fonts\\palabi.ttf',
#  u'C:\\Windows\\Fonts\\phagspa.ttf',
#  u'c:\\windows\\fonts\\lucon.ttf',
#  u'C:\\Windows\\Fonts\\MSMINCHO.TTF',
#  u'C:\\Windows\\Fonts\\PERTIBD.TTF',
#  u'c:\\windows\\fonts\\ravie.ttf',
#  u'C:\\Windows\\Fonts\\consolaz.ttf',
#  u'c:\\windows\\fonts\\leelawui.ttf',
#  u'c:\\windows\\fonts\\erasdemi.ttf',
#  u'C:\\Windows\\Fonts\\LBRITEDI.TTF',
#  u'c:\\windows\\fonts\\yellowtail-regular.ttf',
#  u'C:\\Windows\\Fonts\\Quicksand-Regular.ttf',
#  u'c:\\windows\\fonts\\scriptbl.ttf',
#  u'C:\\Windows\\Fonts\\GOTHICI.TTF',
#  u'C:\\Windows\\Fonts\\MAIAN.TTF',
#  u'C:\\Windows\\Fonts\\Candaral.ttf',
#  u'c:\\windows\\fonts\\calistbi.ttf',
#  u'c:\\windows\\fonts\\oldengl.ttf',
#  u'C:\\Windows\\Fonts\\TCCB____.TTF',
#  u'c:\\windows\\fonts\\mvboli.ttf',
#  u'C:\\Windows\\Fonts\\HARLOWSI.TTF',
#  u'c:\\windows\\fonts\\notosans-regular.ttf',
#  u'C:\\Windows\\Fonts\\PERTILI.TTF',
#  u'C:\\Windows\\Fonts\\BOOKOSBI.TTF',
#  u'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  u'c:\\windows\\fonts\\bellb.ttf',
#  u'C:\\Windows\\Fonts\\LCALLIG.TTF',
#  u'C:\\Windows\\Fonts\\PERB____.TTF',
#  u'C:\\Windows\\Fonts\\TCB_____.TTF',
#  u'C:\\Windows\\Fonts\\BOD_PSTC.TTF',
#  u'c:\\windows\\fonts\\phagspab.ttf',
#  u'c:\\windows\\fonts\\segmdl2.ttf',
#  u'c:\\windows\\fonts\\poorich.ttf',
#  u'c:\\windows\\fonts\\ntailub.ttf',
#  u'c:\\windows\\fonts\\bod_cbi.ttf',
#  u'C:\\Windows\\Fonts\\Candarab.ttf',
#  u'c:\\windows\\fonts\\broadw.ttf']

# %% [markdown]
# ## LaTeX support

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare a curve of square numbers
x = np.linspace(0,200,100) # Prepare 100 evenly spaced numbers from 0 to 200
y1 = x **2 +1005# Prepare an array of y equals to x squared
y2 = x** 2 +2000 # Plot a curve of square numbers
y3 = x **2 +3000
plt.plot(x,y1,label = r'$x^2+1005$')
plt.plot(x,y2,label = r'$x^2+2000$')
plt.plot(x,y3,label =r'$x^2+3000$')
plt.legend()
plt.show()

# %%
print x
print "***"
print y1
# Out:
# [  0.           2.02020202   4.04040404   6.06060606   8.08080808
#   10.1010101   12.12121212  14.14141414  16.16161616  18.18181818
#   20.2020202   22.22222222  24.24242424  26.26262626  28.28282828
#   30.3030303   32.32323232  34.34343434  36.36363636  38.38383838
#   40.4040404   42.42424242  44.44444444  46.46464646  48.48484848
#   50.50505051  52.52525253  54.54545455  56.56565657  58.58585859
#   60.60606061  62.62626263  64.64646465  66.66666667  68.68686869
#   70.70707071  72.72727273  74.74747475  76.76767677  78.78787879
#   80.80808081  82.82828283  84.84848485  86.86868687  88.88888889
#   90.90909091  92.92929293  94.94949495  96.96969697  98.98989899
#  101.01010101 103.03030303 105.05050505 107.07070707 109.09090909
#  111.11111111 113.13131313 115.15151515 117.17171717 119.19191919
#  121.21212121 123.23232323 125.25252525 127.27272727 129.29292929
#  131.31313131 133.33333333 135.35353535 137.37373737 139.39393939
#  141.41414141 143.43434343 145.45454545 147.47474747 149.49494949
#  151.51515152 153.53535354 155.55555556 157.57575758 159.5959596
#  161.61616162 163.63636364 165.65656566 167.67676768 169.6969697
#  171.71717172 173.73737374 175.75757576 177.77777778 179.7979798
#  181.81818182 183.83838384 185.85858586 187.87878788 189.8989899
#  191.91919192 193.93939394 195.95959596 197.97979798 200.        ]
# ***
# [  0.           2.02020202   4.04040404   6.06060606   8.08080808
#   10.1010101   12.12121212  14.14141414  16.16161616  18.18181818
#   20.2020202   22.22222222  24.24242424  26.26262626  28.28282828
#   30.3030303   32.32323232  34.34343434  36.36363636  38.38383838
#   40.4040404   42.42424242  44.44444444  46.46464646  48.48484848
#   50.50505051  52.52525253  54.54545455  56.56565657  58.58585859
#   60.60606061  62.62626263  64.64646465  66.66666667  68.68686869
#   70.70707071  72.72727273  74.74747475  76.76767677  78.78787879
#   80.80808081  82.82828283  84.84848485  86.86868687  88.88888889
#   90.90909091  92.92929293  94.94949495  96.96969697  98.98989899
#  101.01010101 103.03030303 105.05050505 107.07070707 109.09090909
#  111.11111111 113.13131313 115.15151515 117.17171717 119.19191919
#  121.21212121 123.23232323 125.25252525 127.27272727 129.29292929
#  131.31313131 133.33333333 135.35353535 137.37373737 139.39393939
#  141.41414141 143.43434343 145.45454545 147.47474747 149.49494949
#  151.51515152 153.53535354 155.55555556 157.57575758 159.5959596
#  161.61616162 163.63636364 165.65656566 167.67676768 169.6969697
#  171.71717172 173.73737374 175.75757576 177.77777778 179.7979798
#  181.81818182 183.83838384 185.85858586 187.87878788 189.8989899
#  191.91919192 193.93939394 195.95959596 197.97979798 200.        ]

# %%
print x
print "***"
print y2
# Out:
# [  0.           2.02020202   4.04040404   6.06060606   8.08080808
#   10.1010101   12.12121212  14.14141414  16.16161616  18.18181818
#   20.2020202   22.22222222  24.24242424  26.26262626  28.28282828
#   30.3030303   32.32323232  34.34343434  36.36363636  38.38383838
#   40.4040404   42.42424242  44.44444444  46.46464646  48.48484848
#   50.50505051  52.52525253  54.54545455  56.56565657  58.58585859
#   60.60606061  62.62626263  64.64646465  66.66666667  68.68686869
#   70.70707071  72.72727273  74.74747475  76.76767677  78.78787879
#   80.80808081  82.82828283  84.84848485  86.86868687  88.88888889
#   90.90909091  92.92929293  94.94949495  96.96969697  98.98989899
#  101.01010101 103.03030303 105.05050505 107.07070707 109.09090909
#  111.11111111 113.13131313 115.15151515 117.17171717 119.19191919
#  121.21212121 123.23232323 125.25252525 127.27272727 129.29292929
#  131.31313131 133.33333333 135.35353535 137.37373737 139.39393939
#  141.41414141 143.43434343 145.45454545 147.47474747 149.49494949
#  151.51515152 153.53535354 155.55555556 157.57575758 159.5959596
#  161.61616162 163.63636364 165.65656566 167.67676768 169.6969697
#  171.71717172 173.73737374 175.75757576 177.77777778 179.7979798
#  181.81818182 183.83838384 185.85858586 187.87878788 189.8989899
#  191.91919192 193.93939394 195.95959596 197.97979798 200.        ]
# ***
# [2.00000000e+01 2.40812162e+01 3.63248648e+01 5.67309458e+01
#  8.52994592e+01 1.22030405e+02 1.66923783e+02 2.19979594e+02
#  2.81197837e+02 3.50578512e+02 4.28121620e+02 5.13827160e+02
#  6.07695133e+02 7.09725538e+02 8.19918376e+02 9.38273646e+02
#  1.06479135e+03 1.19947148e+03 1.34231405e+03 1.49331905e+03
#  1.65248648e+03 1.81981635e+03 1.99530864e+03 2.17896337e+03
#  2.37078053e+03 2.57076013e+03 2.77890215e+03 2.99520661e+03
#  3.21967350e+03 3.45230283e+03 3.69309458e+03 3.94204877e+03
#  4.19916539e+03 4.46444444e+03 4.73788593e+03 5.01948985e+03
#  5.30925620e+03 5.60718498e+03 5.91327620e+03 6.22752984e+03
#  6.54994592e+03 6.88052444e+03 7.21926538e+03 7.56616876e+03
#  7.92123457e+03 8.28446281e+03 8.65585348e+03 9.03540659e+03
#  9.42312213e+03 9.81900010e+03 1.02230405e+04 1.06352433e+04
#  1.10556086e+04 1.14841363e+04 1.19208264e+04 1.23656790e+04
#  1.28186940e+04 1.32798714e+04 1.37492113e+04 1.42267136e+04
#  1.47123783e+04 1.52062055e+04 1.57081951e+04 1.62183471e+04
#  1.67366616e+04 1.72631385e+04 1.77977778e+04 1.83405795e+04
#  1.88915437e+04 1.94506703e+04 2.00179594e+04 2.05934109e+04
#  2.11770248e+04 2.17688011e+04 2.23687399e+04 2.29768411e+04
#  2.35931048e+04 2.42175309e+04 2.48501194e+04 2.54908703e+04
#  2.61397837e+04 2.67968595e+04 2.74620977e+04 2.81354984e+04
#  2.88170615e+04 2.95067871e+04 3.02046750e+04 3.09107254e+04
#  3.16249383e+04 3.23473135e+04 3.30778512e+04 3.38165514e+04
#  3.45634139e+04 3.53184389e+04 3.60816264e+04 3.68529762e+04
#  3.76324885e+04 3.84201632e+04 3.92160004e+04 4.00200000e+04]

# %% [markdown]
# ___
# # Customizing lines and markers

# %% [markdown]
# ## Lines

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcdefaults()

# Prepare 100 evenly spaced numbers from 0 to 200
evens = np.linspace(0,200,100)
# Plot a curve of square numbers
plt.plot(evens,evens**2,label = '$x^2$',c='burlywood',ls=('dashed'),lw=4)
plt.legend()
plt.savefig('B07915_02_burlywooddash.png',dpi=300)
plt.show()

# %% [markdown]
# ### Setting capstyle of dashes

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 6 lines
x = np.linspace(0,200,100)
y1 = x*0.5
y2 = x
y3 = x*2
y4 = x*3
y5 = x*4
y6 = x*5
# Plot lines with different dash cap styles
plt.plot(x,y1,label = '0.5x', lw=5, ls=':',dash_capstyle='butt')
plt.plot(x,y2,label = 'x', lw=5, ls='--',dash_capstyle='butt')
plt.plot(x,y3,label = '2x', lw=5, ls=':',dash_capstyle='projecting')
plt.plot(x,y4,label = '3x', lw=5, ls='--',dash_capstyle='projecting')
plt.plot(x,y5,label = '4x', lw=5, ls=':',dash_capstyle='round')
plt.plot(x,y6,label = '5x', lw=5, ls='--',dash_capstyle='round')
plt.show()

# %% [markdown]
# ### Advanced example

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare 100 evenly spaced numbers from 0 to 200
x = np.linspace(0,200,100)
# Plot lines with different line styles
plt.plot(x,x*2,label = '2x', lw=2, ls=(0,(1,1)))
plt.plot(x,x*3,label = '3x', lw=2, ls=(0,(5,3,1,3,1,3)))
plt.plot(x,x*4,label = '4x', lw=2, ls=(3,(5,5)))
plt.plot(x,x*5,label = '5x', lw=2, ls=(2,(5,2,1,2)))
plt.savefig('B07915_02_dashdemo.png',dpi=300)
plt.show()

# %% [markdown]
# ## Markers

# %% [markdown]
# ### Choosing markers

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline
# Prepare 100 random numbers to plot
x = np.random.rand(100)
y = np.random.rand(100)

# Prepare 100 random numbers within the range of the number of available markers as index
# Each random number will serve as the choice of marker of the corresponding coordinates
markerindex = np.random.randint(0, len(Line2D.markers), 100)
#print markerindex
# Plot all kinds of available markers at random coordinates 
# for each type of marker, plot a point at the above generated random coordinates with the marker type
for k, m in enumerate(Line2D.markers):
    
    #print k
    i = (markerindex == k)# k -->  0 , with in marker index i have 10  zeros # 
    # len i is 100 ===>> 10 TRUE  , 90 fALSE
    
    #print i
    plt.scatter(x[i], y[i], marker=m)
plt.show()

# %% [markdown]
# ### Adjusting marker sizes

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 5 lines
x = np.linspace(0,20,10)
y1 = x
y2 = x*2
y3 = x*3
y4 = x*4
y5 = x*5
# Plot lines with different marker sizes
plt.plot(x,y1,label = 'x', lw=2, marker='s', ms=10)  # square size 10
plt.plot(x,y2,label = '2x', lw=2, marker='^', ms=12) # triangle size 12
plt.plot(x,y3,label = '3x', lw=2, marker='o', ms=10) # circle size 10
plt.plot(x,y4,label = '4x', lw=2, marker='D', ms=8)  # diamond size 8
plt.plot(x,y5,label = '5x', lw=2, marker='P', ms=12) # filled plus sign size 12

# get current axes and store it to ax
#ax = plt.gca()
plt.legend()
plt.show()

# %% [markdown]
# ___
# # Customizing grids, ticks and axes

# %% [markdown]
# ## Grids

# %% [markdown]
# ### Adding grids
# Sometimes it may not be easy to tell the coordinates of any point in the plot. Grid lines that extend from axis tick marks help us estimate the values at a certain position. Grids can be added by calling `pyplot.grid()`. By default, grid lines will be added at major tick marks. As in other line features, `pyplot.grid()` takes in parameters such as linewidth (lw), linestyle (ls) andn color (c).
# //Insert image

# %%
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()

# Prepare 100 evenly spaced numbers from 0 to 200
evens = np.linspace(0,200,100)
plt.plot(evens,evens**2,label = '$x^2$') # LaTex Math notation support for x squared
plt.grid()
plt.legend()
plt.savefig(B07915_02_defaultgrid.png',dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare 100 evenly spaced numbers from 0 to 200
evens = np.linspace(0,200,100)
plt.plot(evens,evens**2,label = '$x^2$') # LaTex Math notation support for x squared
plt.grid(color='lightblue', linestyle='-.', linewidth=0.6)
plt.legend()
plt.savefig('images/B07915_02_lightbluegrid.png',dpi=300)
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# ## Ticks

# %% [markdown]
# ### Setting label sizes

# %% [markdown]
# ### Trying out the ticker locator and formatter

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
"""
Number for Netflix streaming subscribers from 2012-2017
[ 30 ]Figure Aesthetics
Data were obtained from Statista on
https://www.statista.com/statistics/250934/quarterly-number-of-netflix-stre
aming-subscribers-worldwide/ on May 10, 2017. The data were originally
published by Netflix in April 2017.
"""
# Prepare the data set
x = range(2011,2018)
y = [26.48,27.56,29.41,33.27,36.32,37.55,40.28,44.35,48.36,50.05,53.06,57.39,\
     62.27,65.55,69.17,74.76,81.5,83.18,86.74,93.8,98.75] # quarterly subscriber count in millions
# Plot lines with different line styles
plt.plot(y,'^',label = 'Netflix subscribers',ls='-')
# get current axes and store it to ax
ax = plt.gca()
# set ticks in multiples for both labels
ax.xaxis.set_major_locator(ticker.MultipleLocator(4)) # set major marks every 4 quarters, ie once a year
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1)) # set minor marks for each quarter
ax.yaxis.set_major_locator(ticker.MultipleLocator(10)) 
ax.yaxis.set_minor_locator(ticker.MultipleLocator(2))
# label the start of each year by FixedFormatter
ax.get_xaxis().set_major_formatter(ticker.FixedFormatter(x))
plt.legend()
plt.show()

# %% [markdown]
# ### Rotating tick labels

# %%
import matplotlib.pyplot as plt
import numpy as np

techs = ['Google Adsense','DoubleClick.Net','Facebook Custom Audiences','Google Publisher Tag', 'App Nexus']
y_pos = np.arange(len(techs))
# Number of websites using the advertising technologies
# Data were quoted from builtwith.com on May 8th 2017
websites = [14409195,1821385,948344,176310,283766]
plt.bar(y_pos, websites, align='center', alpha=0.5)
# set x-axis tick rotation
plt.xticks(y_pos, techs, rotation=25)
plt.ylabel('Live site count')
plt.title('Online advertising technologies usage')
plt.show()

# %% [markdown]
# ## Axes

# %% [markdown]
# ## Nonlinear axes

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 100 evenly spaced numbers from 0 to 200
x = np.linspace(0, 200, 100)
y = x * 2
plt.figure()
plt.plot(x,y)

# Plot an outlier point
plt.plot([100], [100000], 'o')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ### Logarithmic scale

# %%
plt.figure()

plt.plot(x,y)
# Plot an outlier point
plt.plot([100], [100000], 'o')

plt.xlabel('x')
plt.ylabel('y')

#Change y-axis to log10 scale
plt.yscale('log')

plt.show()

# %% [markdown]
# ### Changing the base of log scale

# %%
plt.figure()

plt.plot(x,y)
# Plot an outlier point
plt.plot([100], [100000], 'o')

plt.xlabel('x')
plt.ylabel('y')

#Change y-axis to log2 scale
plt.yscale('log', basey=2)

plt.show()

# %% [markdown]
# #### Advanced example

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

def ticks(y, pos):
    """ Method that formats the axis labels to natural log scale 
    """
    
    # Use Python string formatter to limit the number of decimal places for float values. 
    # The precision of the formatted float value can be specified using a full stop, followed 
    # by the number of decimal places you would like to include.
    #
    # Latex notation is denoted by $$ in Matplotlib.
    # The outer double curly braces {{ }} will be escaped by Python to {}, while the innermost
    # curly braces contains the actual Python float format string. As an example, 7.389 will
    # be converted to $e^{2}$ in latex notation.
    return r'$e^{{{:.0f}}}$'.format(np.log(y))


x = np.linspace(0, 200, 100)
y = x * 2

plt.figure()

# The two keyword arguments, basex and basey, can be specified together in plt.loglog(). 
# Note: natural log scale is used on the y axis by supplying numpy.e to basey
plt.loglog(x,y, basex=2, basey=np.e)

# Plot an outlier point
plt.plot([100], [100000], 'o')

# Get the current axes in this plot
ax = plt.gca()
# Apply the tick formatter to the y-axis
ax.yaxis.set_major_formatter(FuncFormatter(ticks))

plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %% [markdown]
# ## Symmetrical logarithmic scale

# %% [markdown]
# The base a logarithm of a negative number is undefined. If we try to supply non-positive numbers (≤0) to numpy.log(), we see the following errors:

# %%
np.log(0)
# Output: -inf

np.log(-1)
# Output: nan
# Out:
# /home/claire/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# /home/claire/.local/lib/python3.5/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.
# nan

# %%
import numpy as np
import matplotlib.pyplot as plt

# Prepare 100 evenly spaced numbers from -200 to 200
x = np.linspace(-200, 200, 100)
y = x * 2

# Setup subplot with 3 rows and 2 columns, with shared x-axis.
# More details about subplots will be discussed in Chapter 3.
f, axarr = plt.subplots(nrows=3, ncols=2, figsize=(8,10), sharex=True)

# Linear scale
axarr[0, 0].plot(x, y)
axarr[0, 0].plot([-200,200], [10,10]) # Horizontal line (y=10)
axarr[0, 0].set_title('Linear scale')

# Log scale, mask non-positive numbers
axarr[0, 1].plot(x,y)
axarr[0, 1].plot([-200,200], [10,10])
axarr[0, 1].set_title('Log scale, nonposy=mask')
axarr[0, 1].set_yscale('log', nonposy='mask') # Note: axes object requires set_yscale instead of yscale method.

# Log scale, clip non-positive numbers
axarr[1, 0].plot(x,y)
axarr[1, 0].plot([-200,200], [10,10])
axarr[1, 0].set_title('Log scale, nonposy=clip')
axarr[1, 0].set_yscale('log', nonposy='clip')

# Symlog scale
axarr[1, 1].plot(x,y)
axarr[1, 1].plot([-200,200], [10,10])
axarr[1, 1].set_title('Symlog scale')
axarr[1, 1].set_yscale('symlog')

# Symlog scale, expand the linear range to -50,50 (default=None)
axarr[2, 0].plot(x,y)
axarr[2, 0].plot([-200,200], [10,10])
axarr[2, 0].set_title('Symlog scale, linthreshy=50')
axarr[2, 0].set_yscale('symlog', linthreshy=50)

# Symlog scale, expand the linear scale to 3 (default=1)
# The linear region is expanded, while the log region is compressed.
axarr[2, 1].plot(x,y)
axarr[2, 1].plot([-200,200], [10,10])
axarr[2, 1].set_title('Symlog scale, linscaley=3')
axarr[2, 1].set_yscale('symlog', linscaley=3)

plt.show()

# %% [markdown]
# ## Logit scale

# %%
import numpy as np
import matplotlib.pyplot as plt
# Prepare 1000 sorted random numbers from the normal distribution
np.random.seed(1)
y = np.random.normal(0.5, 0.1, 1000)
y.sort()
x = np.arange(len(y))
plt.figure()
plt.plot(x,y)

# Transform x-axis to logit scale
plt.yscale('logit')
plt.show()

# %% [markdown]
# ___
# # Using style sheet

# %%
import matplotlib as mpl
mpl.style.available # check the available stylesheets
# Out:
# ['seaborn-ticks',
#  'ggplot',
#  'seaborn',
#  'dark_background',
#  'bmh',
#  'seaborn-poster',
#  'seaborn-whitegrid',
#  'seaborn-darkgrid',
#  'fivethirtyeight',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-notebook',
#  'grayscale',
#  'seaborn-white',
#  '_classic_test',
#  'seaborn-muted',
#  'seaborn-paper',
#  'seaborn-talk',
#  'seaborn-deep',
#  'seaborn-dark-palette',
#  'seaborn-pastel',
#  'classic']

# %% [markdown]
# ## Applying a stylesheet

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
# set the style as 'bmh'
mpl.style.use('bmh')
months = ['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']
y_pos = np.arange(len(months))
# 2016 Hong Kong monthly mean temperature
# Data were quoted from Hong Kong Observatory data on May 8th 2017
# http://www.hko.gov.hk/wxinfo/pastwx/2016/ywx2016.htm
meantemp = [16.,15.5,17.5,23.6,26.7,29.4,29.8,28.4,27.9,26.8,22.3,19.6]
plt.bar(y_pos, meantemp, align='center', alpha=0.5)
plt.xticks(y_pos, months)
plt.ylabel('Temperature (ºC)')
plt.title('Hong Kong 2016 monthly mean temperature')
plt.show()

# %% [markdown]
# ## Resetting to default styles

# %%
plt.rcdefaults()

# %%
# alternate method to reset to default parameters
import matplotlib as mpl 
mpl.rcParams.update(mpl.rcParamsDefault)

# %% [markdown]
# ___
# # Titles and legends

# %% [markdown]
# ## Test your skills

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np 
import matplotlib as mpl

mpl.style.use('seaborn-darkgrid')

# 2001-2015 per genome sequencing cost in USD
# Adapted from NIH National Human Genome Research Institute figures
# genome.gov/sequencingcosts
# Data were quoted from builtwith.com on May 8th 2017
# Seasonal data were averaged by year for simplicity

# Prepare the data
years = list(range(2001,2016))
y_pos = np.arange(len(years)) 
seqcost = [95263071.92,70175437.42,61448421.50,53751684.08,40157554.23,28780376.21,\
 20442576.14,19934345.74,18519312.16,17534969.56,16159699.44,16180224.10,\
 13801124.19,12585658.90,11732534.52,11455315.22,10474556.36,9408738.91,\
 9047002.97,8927342.14,7147571.39,3063819.99,1352982.23,752079.90,342502.06,\
 232735.44,154713.60,108065.14,70333.33,46774.27,31512.04,31124.96,29091.73,\
 20962.78,16712.01,10496.93,7743.44,7666.22,5901.29,5984.72,6618.35,5671.35,\
 5826.26,5550.26,5096.08,4008.11,4920.50,4904.85,5730.89,3969.84,4210.79,1363.24,1245.00]

# Plot the data
plt.plot(seqcost,marker='D',ms=3,color='navy',label='Genome sequencing cost') 
plt.xticks(y_pos, years) 

# Set logarithmic scale on y-axis
plt.yscale('log')
plt.title('2001-2015 per Genome Sequencing Cost',color='darkblue',fontweight='semibold') 
plt.legend()

# Get current axes
ax = plt.gca()

# Set ticks in multiples for x-axis
ax.xaxis.set_major_locator(ticker.MultipleLocator(4))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1))

# label the start of each year by FixedFormatter
ax.get_xaxis().set_major_formatter(ticker.FixedFormatter(years))

# Label the axes
ax.set_xlabel('Year')
ax.set_ylabel('Per Genome Sequencing Cost (USD)')

ax.xaxis.set_tick_params(labelsize=10)

plt.show()
